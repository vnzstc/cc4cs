# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
atmega_df = pd.read_csv('/home/xeder/Desktop/material/cc4cs/cc4cs/benchmark/custom/bubblesort/atmega328/int8/atmega328_report.csv', sep = ';')

# %%
intel_df = pd.read_csv('/home/xeder/Desktop/material/cc4cs/cc4cs/benchmark/custom/bubblesort/8051/int8/bubble_sort_op_I8051Report.csv', sep = ';')

# %%
leon_df = pd.read_csv('/home/xeder/Desktop/material/cc4cs/cc4cs/benchmark/custom/bubblesort/sparc_leon3 /int8/bubble_sort_op_sparcReport.csv', sep = ';')

# %%
result_df = pd.DataFrame({'atmega' : atmega_df[' CC4CS'], 'Leon3' : leon_df[' Average Clock Cycle per Instruction']})

# %%
print("Leon3 ###############")
print("Min: ", leon_df[' Average Clock Cycle per Instruction'].min())
print("Max: ", leon_df[' Average Clock Cycle per Instruction'].max())
print("Median: ", leon_df[' Average Clock Cycle per Instruction'].median())
print("Standard Deviation: ", leon_df[' Average Clock Cycle per Instruction'].std())
print("Mean: ", leon_df[' Average Clock Cycle per Instruction'].mean())
# Out:
# Leon3 ###############
# Min:  11.3476880133
# Max:  1648.8
# Median:  14.0085325307
# Standard Deviation:  241.752402698
# Mean:  71.1289045085

# %%
# result_df.boxplot()

# %%
print("Atmega328p ###############")
print("Min: ", atmega_df[' CC4CS'].min())
print("Max: ", atmega_df[' CC4CS'].max())
print("Median: ", atmega_df[' CC4CS'].median())
print("Standard Deviation: ", atmega_df[' CC4CS'].std())
print("Mean: ", atmega_df[' CC4CS'].mean())
# Out:
# Atmega328p ###############
# Min:  9.031
# Max:  11.631
# Median:  11.3395
# Standard Deviation:  0.450779627392
# Mean:  11.152849

# %%
print("8051 ###############")
print("Min: ", intel_df[' Average Clock Cycle per Instruction'].min())
print("Max: ", intel_df[' Average Clock Cycle per Instruction'].max())
print("Median: ", intel_df[' Average Clock Cycle per Instruction'].median())
print("Standard Deviation: ", intel_df[' Average Clock Cycle per Instruction'].std())
print("Mean: ", intel_df[' Average Clock Cycle per Instruction'].mean())
# Out:
# 8051 ###############
# Min:  83.0546737213
# Max:  270.0
# Median:  89.8063404158
# Standard Deviation:  26.5474979797
# Mean:  94.8333847856

# %%
atmega_df = pd.read_csv('/home/xeder/Desktop/material/cc4cs/cc4cs/new_test/results_atmega328p/int8_t/cc4csValues.csv', sep = ',')
leon3_df = pd.read_csv('/home/xeder/Desktop/material/cc4cs/cc4cs/new_test/results_leon3/int8_t/cc4csValues.csv', sep = ',')

# %%
result_df = pd.DataFrame({'atmega' : atmega_df['CC4CS'], 'Leon3' : leon3_df['CC4CS']})

# %%
result_df.boxplot()
# Out:
# <img src="data:image/png;base64,..." width="640">
